# %% [markdown]
# <a href="https://colab.research.google.com/github/be1le/Crawling/blob/master/%ED%81%AC%EB%A1%A4%EB%A7%81%ED%95%9C_%EC%9E%90%EB%A3%8C%ED%99%9C%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_table('news_data.csv', sep=',')

# %%
# !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
# Out:
# Cloning into 'Mecab-ko-for-Google-Colab'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 109 (delta 7), reused 10 (delta 3), pack-reused 91
# Receiving objects: 100% (109/109), 1.27 MiB | 8.72 MiB/s, done.
# Resolving deltas: 100% (46/46), done.

# %%
cd 'Mecab-ko-for-Google-Colab'
# Out:
# /content/Mecab-ko-for-Google-Colab

# %%
# !bash install_mecab-ko_on_colab_light_220111.sh
# Out:
# Installing konlpy.....
# ...
#      |████████████████████████████████| 19.4 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 448 kB 51.3 MB/s
# ...
# Done
# Installing mecab-0.996-ko-0.9.2.tar.gz.....
# ...
# from https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# --2022-01-26 01:49:23--  https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz
# Resolving bitbucket.org (bitbucket.org)... 104.192.141.1, 2406:da00:ff00::6b17:d1f5, 2406:da00:ff00::22c5:2ef4, ...
# Connecting to bitbucket.org (bitbucket.org)|104.192.141.1|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://bbuseruploads.s3.amazonaws.com/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz?Signature=Se%2BsFG08gFzMRatOf2HsowgDYws%3D&Expires=1643162726&AWSAccessKeyId=AKIA6KOSE3BNA7WTAGHW&versionId=null&response-content-disposition=attachment%3B%20filename%3D%22mecab-0.996-ko-0.9.2.tar.gz%22&response-content-encoding=None [following]
# ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()
df['token'] = 0

# %%
stopwords=['뉴스', '기자', '무단', '전재', '배포', '금지', '앵커', '저작권자', '파이낸셜', '조선일보', '동아일보', '연합뉴스', '리포터'] 
for i in range(0, len(df['news'])):
  tmp = mecab.nouns(df['news'][i])
  tokens = []
  for token in tmp:
    if not token in stopwords:
      tokens.append(token)
    df['token'][i] = tokens
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:670: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value)

# %%
df
# Out:
#                                                   news  ...                                              token
# 0    (뉴욕=연합뉴스) 윤영숙 연합인포맥스 특파원 = 뉴욕증시는 연방준비제도(연준·Fed...  ...  [뉴욕, 윤영숙, 연합, 인포, 맥스, 특파원, 뉴욕, 증시, 연방, 준비, 제도,...
# 1    박종석 정신과 전문의 /고운호 기자 박종석 정신과 전문의 /고운호 기자\n\n주식으...  ...  [박종석, 정신, 전문의, 호, 박종석, 정신, 전문의, 호, 주식, 재산, 의사,...
# 2    미국 뉴욕증권거래소(NYSE). © AFP=뉴스1 자료 사진 미국 뉴욕증권거래소(N...  ...  [미국, 뉴욕, 증권거래소, 자료, 사진, 미국, 뉴욕, 증권거래소, 자료, 사진,...
# 3    25일(현지시간) 독일 뒤스부르크 항구에서 선적을 기다리는 수출 차량들.AP뉴시스 ...  ...  [일, 현지, 시간, 독일, 뒤스부르크, 항구, 선적, 수출, 차량, 뉴시스, 일,...
# 4    뉴욕증시가 하락 출발했다.\n\n\n\n25일(현지시간) 오전 9시35분 현재 뉴욕...  ...  [뉴욕, 증시, 하락, 출발, 일, 현지, 시간, 오전, 시, 분, 뉴욕, 증시, ...
# ..                                                 ...  ...                                                ...
# 295  【짬】\n\n회원 10여명 산문집 낸 고양시 문학공부반\n\n경기 고양시 문학공부반...  ...  [짬, 회원, 명, 산문, 집, 고양시, 문학, 공부, 반, 경기, 고양시, 문학,...
# ...

# %%
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
documents = [TaggedDocument(doc,[i]) for i, doc in enumerate(df['token'])]
model = Doc2Vec(documents, vector_size=100, window=3, epochs=10, min_count=0,workers=4)

# %%
inferred_doc_vec = model.infer_vector(df['token'][20])
print(inferred_doc_vec)
# Out:
# [ 0.12820306  0.6219572  -0.8624616  -0.32338524 -0.66413236  0.13949305
#   0.7138943   0.76722646 -0.0888641   1.4438158   0.84428626  0.24547018
#   1.0137286   0.07229068  0.34117308 -0.11992056 -0.6740053  -0.1886339
#   0.9011111   0.15749212  0.63242114  0.36773372  0.41287386  0.48251355
#  -0.6684413  -0.20852345 -0.74557257  0.5994857   0.9948849  -0.30144635
#   1.1831212   0.1596989   0.42374206 -0.1547249   0.7458834  -0.09758003
#  -0.13232718  0.37049657 -0.60078937  0.28524363  0.2780149  -0.3416377
#  -0.18520626  0.07127175  0.49385476  0.79107606 -0.26840103  0.7781989
#  -0.3699383  -0.17963332 -0.13853528 -0.46523178 -0.87606937  0.32357275
#   0.9125641   0.48595637 -0.30617964 -0.39829007 -0.78879046 -0.65596575
#  -0.38836005 -0.24032666 -0.3778007  -0.2574779   0.03450764 -0.78268427
#   0.20034899 -0.8744586   0.3713955  -0.08410767 -0.33700392 -1.0075153
#  -0.14167665  0.18543345  0.0421221  -0.18707736 -0.9321311  -0.38820624
# ...

# %%
print(df['token'][20])
# Out:
# ['수소', '산업', '수소', '경제', '산업', '통상', '자원', '부', '블로그', '사진', '캡처', '수소', '산업', '수소', '경제', '산업', '통상', '자원', '부', '블로그', '사진', '캡처', '정부', '재생', '에너지', '활용', '수소', '대량', '생산', '실증', '사업', '본격', '추진', '산업', '통상', '자원', '부', '올해', '년', '년', '억', '원', '투입', '수소', '생산', '메가와트', '급', '수전', '실증', '진행', '일', '수전', '시스템', '전기', '물', '분해', '산소', '수소', '생산', '설비', '재생', '에너지', '전력', '사용', '경우', '이산화', '탄소', '배출', '수소', '생산', '수', '핵심', '기술', '국내', '년', '제주', '상명', '풍력', '단지', '킬로와트', '급', '수전', '기술', '개발', '실증', '사업', '시작', '급', '울산', '급', '동해', '급', '제주', '행원', '등', '규모', '수전', '실증', '사업', '단계', '진행', '유럽', '북미', '등', '해외', '주요', '국', '규모', '수소', '생산', '계획', '급', '이상', '대용량', '수전', '실증', '프로젝트', '다수', '추진', '중', '이', '우리', '정부', '수소', '생산', '기반', '확충', '규모', '수전', '실증', '추진', '실증', '사업', '규모', '재생', '에너지', '단지', '전력', '공급', '수소', '생산', '실증', '전력', '공급', '피크', '시', '출력', '어량', '잉여', '전력', '공급', '계통', '수급', '안정', '기여', '수', '확인', '방식', '진행', '이', '국내', '기업', '수전', '시스템', '최적', '운전', '경험', '수소',
# ...

# %%
most_similar_docs = model.docvecs.most_similar([inferred_doc_vec], topn=10)

for index, similarity in most_similar_docs:
  print(f'{index}, similarity: {similarity}')
  print(documents[index])
# Out:
# 65, similarity: 0.991399347782135
# ...
